# %% [markdown]
# # Exploratory Data Analysis for WATER DEMAND
# - Coded by Kyungwon Joo
# - AI Research Laboratory / K-water Research Institute

# %% [markdown]
# References
# - 1_영향변수_분석.ipynb (최영돈)

# %% [markdown]
# 용수공급량 예측을 위한 방향성에는 크게 두가지가 있음
# - 각 지자체마다 개별 모델을 생성 (시계열)
# - 전체 지자체를 포함하는 일반 모형 (꼭 시계열이 아니어도 됨)

# %% [markdown]
# # LOAD REQUIRED PACKAGES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

sns.set(font_scale = 1.5)
plt.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='Malgun Gothic')

# %%
print('package version info.')
print(f'pandas : {pd.__version__}')
print(f'numpy : {np.__version__}')
print(f'sklearn : {sklearn.__version__}')
# Out:
# package version info.
# pandas : 1.4.3
# numpy : 1.19.5
# sklearn : 0.23.2

# %% [markdown]
# # CASE STUDY : 서울특별시

# %%
CITY_NAME = '서울특별시'

# %% [markdown]
# ## Load Dataset

# %% [markdown]
# ### 입력자료

# %%
data_raw = pd.read_excel("../data/01_시군별_영향인자(독립변수)/특광역시/특별시 및 광역시 종합.xlsx", sheet_name=CITY_NAME)

# %%
data_raw.head(5)
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0         지역         코드        NaN        NaN        NaN        NaN
# 1      서울특별시         11        지역성        NaN        NaN        NaN
# 2         연도          월    총인구수(명)     세대수(개)  세대당 인구(명)  남자 인구수(명)
# 3       2001          1        NaN        NaN        NaN        NaN
# 4       2001          2        NaN        NaN        NaN        NaN
#
#   Unnamed: 6  Unnamed: 7        Unnamed: 8  Unnamed: 9  ...      Unnamed: 28  \
# 0        NaN         NaN               NaN         NaN  ...              NaN
# 1        NaN         NaN               NaN         NaN  ...              NaN
# 2  여자 인구수(명)  남여 비율(남/여)  65세 이상\n고령화비율(%)  전력사용량(kWh)  ...  기압\n평균현지기압(hPa)
# 3        NaN         NaN               NaN         NaN  ...           1012.9
# 4        NaN         NaN               NaN         NaN  ...           1013.3
#
#   Unnamed: 29          Unnamed: 30 Unnamed: 31 Unnamed: 32    Unnamed: 33  \
# 0         NaN                  NaN         NaN         NaN            NaN
# 1         NaN                   일시         계절성         NaN            NaN
# 2         NaN                  년월일   평균 기온(°C)   일합강수량(mm)  습도\n평균상대습도(%)
# 3         NaN  2001-01-01 00:00:00        -4.5         1.2           63.5
# 4         NaN  2001-01-02 00:00:00        -4.3         NaN             59
#
#         Unnamed: 34       Unnamed: 35    Unnamed: 36      Unnamed: 37
# 0               NaN               NaN            NaN              NaN
# 1               NaN               NaN            NaN              NaN
# 2  일조량\n합계 일조시간(hr)  지중온도\n평균지면온도(°C)  풍량\n평균풍속(m/s)  기압\n평균현지기압(hPa)
# 3               2.6              -3.7            1.7           1006.3
# 4                 0              -2.4            2.8           1007.9
#
# [5 rows x 38 columns]

# %% [markdown]
# - 3번째 index까지 data header에 해당하므로 지역명 및 지역코드만 취하고 날려줄 것
# - 왼쪽과 오른쪽의 시간스텝이 다름 (왼쪽: 월, 오른쪽: 일)

# %%
## 왼쪽 및 오른쪽 컬럼명
data_raw.iloc[2].values
# Out:
# array(['연도', '월', '총인구수(명)', '세대수(개)', '세대당 인구(명)', '남자 인구수(명)',
#        '여자 인구수(명)', '남여 비율(남/여)', '65세 이상\n고령화비율(%)', '전력사용량(kWh)',
#        '산업체 수(개)', '산업체 규모(개)\n100인 이상 사업장', '산업단지면적(㎡)',
#        '연간 가계소득\n주민1인당 자체수입액(천원)', '연간 학력수준\n고등학교 졸업(명)',
#        '연간 학력수준\n고등학교 졸업자 비율\n(졸업자/만18세 인구)', '연간 인건비(천원)',
#        '연간 평균 수입대비 인건비(%)', '취업률(명)\n고용보험자수', '취업률\n고용보험자 비율\n(피보험자/총인구)',
#        '취약계층(개)\n장애인포함가구', '취약계층(비율)\n장애인포함가구', '평균 기온(°C)', '월합강수량(mm)',
#        '습도\n평균상대습도(%)', '일조량\n합계 일조시간(hr)', '지중온도\n평균지면온도(°C)',
#        '풍량\n평균풍속(m/s)', '기압\n평균현지기압(hPa)', nan, '년월일', '평균 기온(°C)',
#        '일합강수량(mm)', '습도\n평균상대습도(%)', '일조량\n합계 일조시간(hr)',
#        '지중온도\n평균지면온도(°C)', '풍량\n평균풍속(m/s)', '기압\n평균현지기압(hPa)'],
#       dtype=object)

# %% [markdown]
# - 일단위 자료는 '기온', '일강수량', '습도', '일조량', '지중온도', '풍량', '기압' 등으로 월간 자료에도 포함되어 있음
# > 일단위 자료는 제거하고 수행

# %%
CITY_CODE = data_raw.iloc[1, 1]

# %%
data = data_raw.iloc[3:, :29] # header 및 일단위자료 삭제
data.columns = data_raw.iloc[2, :29] # set column names

# %%
data.head(3)
# Out:
# 2    연도  월 총인구수(명) 세대수(개) 세대당 인구(명) 남자 인구수(명) 여자 인구수(명) 남여 비율(남/여)  \
# 3  2001  1     NaN    NaN       NaN       NaN       NaN        NaN
# 4  2001  2     NaN    NaN       NaN       NaN       NaN        NaN
# 5  2001  3     NaN    NaN       NaN       NaN       NaN        NaN
#
# 2 65세 이상\n고령화비율(%) 전력사용량(kWh)  ... 취업률\n고용보험자 비율\n(피보험자/총인구) 취약계층(개)\n장애인포함가구  \
# 3              NaN        NaN  ...                       NaN              NaN
# 4              NaN        NaN  ...                       NaN              NaN
# 5              NaN        NaN  ...                       NaN              NaN
#
# 2 취약계층(비율)\n장애인포함가구 평균 기온(°C) 월합강수량(mm) 습도\n평균상대습도(%) 일조량\n합계 일조시간(hr)  \
# 3               NaN      -4.1      39.4            62               97
# 4               NaN      -0.3      45.7            60              117
# 5               NaN         5      18.1            51              151
#
# 2 지중온도\n평균지면온도(°C) 풍량\n평균풍속(m/s) 기압\n평균현지기압(hPa)
# 3             -3.6           2.2          1012.9
# 4             -0.2           2.1          1013.3
# 5              5.4           2.8          1004.8
#
# [3 rows x 29 columns]

# %% [markdown]
# ### 출력자료 (종속변수)

# %%
data_y = pd.read_excel("../data/01_(종합)종속변수 데이터.xlsx", sheet_name="종합(도별 정렬)", header=1)
data_y.set_index("지자체명", inplace=True)
data_y = data_y.iloc[1:, 1:2]
data_y.rename(columns = {CITY_NAME:f'물공급량\n({CITY_NAME})'}, inplace = True)
data_y = data_y.astype(float)

# %% [markdown]
# ## Set Index and Datatype
# - 일단위 자료 때문에 발생했던 자료 길이 수정
# - 컬럼명 간소화 및 dtype 변경

# %%
data_len = data['연도'].isna().argmax()
data = data[:data_len]

# %%
data.index = pd.to_datetime(data['연도'][:data_len].astype(str) + '-' + data['월'][:data_len].astype(str))
data.rename_axis(columns='', inplace=True)
data.drop(columns=['연도', '월'], inplace=True)

# %%
data_y.index = pd.to_datetime(data_y.index)
data_y.index.name = ""

# %%
# Simplify Column names
data.columns = ['총인구수', '세대수', '세대당 인구', '남자 인구수', '여자 인구수', '남여 비율', '고령화비율', '전력사용량', '산업체 수', '100인 이상 사업장', '산업단지면적', '연간 가계소득',
                '연간 고등학교 졸업(명)', '연간 고등학교 졸업자 비율', '연간 인건비', '연간 평균 수입대비 인건비', '취업률(명)', '고용보험자 비율', '취약계층(개)', '취약계층(비율)',
                '기온', '월강수량', '습도', '일조량', '지중온도', '풍량', '기압']

# %%
# Change datatype from object to float
data = data.astype(float)

# %%
data.describe()
# Out:
#                총인구수           세대수      세대당 인구        남자 인구수        여자 인구수  \
# count  1.680000e+02  1.680000e+02  168.000000  1.680000e+02  1.680000e+02
# mean   1.001952e+07  4.217975e+06    2.377514  4.931634e+06  5.087883e+06
# std    2.253997e+05  9.234473e+04    0.099652  1.439320e+05  8.195161e+04
# min    9.509458e+06  4.054493e+06    2.148541  4.618040e+06  4.891418e+06
# 25%    9.812171e+06  4.182342e+06    2.313056  4.801640e+06  5.010531e+06
# 50%    1.010486e+07  4.195255e+06    2.408376  4.979646e+06  5.125579e+06
# 75%    1.020632e+07  4.242082e+06    2.443871  5.062162e+06  5.150921e+06
# max    1.032892e+07  4.427814e+06    2.516136  5.120401e+06  5.208514e+06
#
#             남여 비율       고령화비율         전력사용량          산업체 수  100인 이상 사업장  ...  \
# count  168.000000  168.000000  2.400000e+02     180.000000   180.000000  ...
# mean     0.969089   12.169048  3.770575e+09  416768.422222  4979.488889  ...
# std      0.013110    2.460051  4.371923e+08   66031.811597   386.217490  ...
# min      0.944111    8.300000  2.844225e+09  316963.000000  4076.000000  ...
# 25%      0.958310    9.975000  3.441126e+09  346211.000000  4594.250000  ...
# 50%      0.971784   12.050000  3.690878e+09  426788.500000  5147.500000  ...
# 75%      0.981169   14.125000  4.093453e+09  476176.250000  5298.500000  ...
# max      0.986706   16.800000  5.394746e+09  527480.000000  5455.000000  ...
#
#          고용보험자 비율       취약계층(개)    취약계층(비율)          기온         월강수량  \
# count  168.000000    108.000000  108.000000  252.000000   252.000000
# mean     0.388216  62932.055556    0.014742   12.933730   116.784921
# std      0.046792   9942.913696    0.002025    9.969636   166.437911
# min      0.306588  51014.000000    0.012209   -7.200000     0.000000
# 25%      0.345738  53109.750000    0.012647    3.900000    24.475000
# 50%      0.388353  59744.500000    0.014183   14.050000    56.600000
# 75%      0.430562  71032.000000    0.016468   22.250000   138.775000
# max      0.471206  83072.000000    0.018769   28.800000  1131.000000
#
#                습도         일조량        지중온도          풍량           기압
# count  252.000000  252.000000  252.000000  252.000000   252.000000
# mean    60.769841  179.157540   14.238492    2.347222  1005.948016
# std      8.422757   49.733184   10.780789    0.420340     6.440902
# min     43.000000   34.300000   -4.700000    1.000000   994.700000
# 25%     55.000000  153.000000    3.800000    2.100000   999.475000
# 50%     59.500000  181.500000   15.350000    2.350000  1006.550000
# 75%     66.250000  210.075000   24.625000    2.600000  1011.725000
# max     85.000000  314.000000   31.900000    3.500000  1016.800000
#
# [8 rows x 27 columns]

# %%
data.tail(5)
# Out:
#                  총인구수        세대수    세대당 인구     남자 인구수     여자 인구수     남여 비율  \
# 2021-08-01  9550227.0  4416816.0  2.162242  4640740.0  4909487.0  0.945260
# 2021-09-01  9542256.0  4421143.0  2.158323  4636069.0  4906187.0  0.944943
# 2021-10-01  9532428.0  4422587.0  2.155396  4630630.0  4901798.0  0.944680
# 2021-11-01  9520880.0  4424222.0  2.151990  4624290.0  4896590.0  0.944390
# 2021-12-01  9509458.0  4426007.0  2.148541  4618040.0  4891418.0  0.944111
#
#             고령화비율         전력사용량     산업체 수  100인 이상 사업장  ...  고용보험자 비율  \
# 2021-08-01   16.5  5.103868e+09  518938.0       5260.0  ...  0.464023
# 2021-09-01   16.6  4.145083e+09  509936.0       5260.0  ...  0.466638
# 2021-10-01   16.7  3.578614e+09  520056.0       5266.0  ...  0.469176
# 2021-11-01   16.7  3.537141e+09  524947.0       5267.0  ...  0.471206
# 2021-12-01   16.8  3.963700e+09  514131.0       5269.0  ...  0.470579
#
#             취약계층(개)  취약계층(비율)    기온   월강수량    습도    일조량  지중온도   풍량      기압
# 2021-08-01  81990.0  0.018563  25.9  211.2  74.0  127.3  28.2  2.1   998.6
# 2021-09-01  82119.0  0.018574  22.6  131.0  71.0  182.0  24.6  2.3  1003.4
# 2021-10-01  82328.0  0.018615  15.6   57.0  70.0  168.4  16.7  2.1  1011.0
# 2021-11-01  82647.0  0.018681   8.2   62.4  68.0  163.6   7.9  2.1  1009.1
# 2021-12-01  83072.0  0.018769   0.6    7.9  62.0  185.4   0.8  2.3  1014.4
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Check Data Availability

# %%
fig, ax = plt.subplots(figsize=(20,5))
sns.heatmap(data.isnull(), cbar=False)
plt.show()

# %% [markdown]
# - 데이터 시작시간이 달라 고려해야 할 부분이 좀 있음

# %% [markdown]
# ## 수도공급량

# %%
plt.figure(figsize=(25,5))
plt.plot(data_y)
plt.show()

# %% [markdown]
# - 2000~2003년은 문제가 있음
# - 일단 2003년 이전은 사용하지 않는 것으로

# %% [markdown]
# ## Set Data Range
# - 가장 자료가 최근에 생성된 ```취약계층(개/비율)``` 로 세팅 (2013년~)

# %%
data_X = data['2013-01':]
data_y = data_y['2013-01':]
data_Xy = pd.concat([data_X, data_y], axis=1)

# %%
pd.concat([data_X, data_y], axis=1)
# Out:
#                   총인구수        세대수    세대당 인구     남자 인구수     여자 인구수     남여 비율  \
# 2013-01-01  10195064.0  4178537.0  2.439864  5040263.0  5154801.0  0.977780
# 2013-02-01  10196434.0  4181574.0  2.438420  5039921.0  5156513.0  0.977389
# 2013-03-01  10192057.0  4182314.0  2.436942  5037288.0  5154769.0  0.977209
# 2013-04-01  10185955.0  4182017.0  2.435656  5033615.0  5152340.0  0.976957
# 2013-05-01  10181807.0  4181819.0  2.434779  5030777.0  5151030.0  0.976655
# ...                ...        ...       ...        ...        ...       ...
# 2021-08-01   9550227.0  4416816.0  2.162242  4640740.0  4909487.0  0.945260
# 2021-09-01   9542256.0  4421143.0  2.158323  4636069.0  4906187.0  0.944943
# 2021-10-01   9532428.0  4422587.0  2.155396  4630630.0  4901798.0  0.944680
# 2021-11-01   9520880.0  4424222.0  2.151990  4624290.0  4896590.0  0.944390
# 2021-12-01   9509458.0  4426007.0  2.148541  4618040.0  4891418.0  0.944111
#
#             고령화비율         전력사용량     산업체 수  100인 이상 사업장  ...  취약계층(개)  \
# 2013-01-01   10.9  4.281117e+09  380773.0       4898.0  ...  51014.0
# 2013-02-01   11.0  4.023566e+09  385191.0       4883.0  ...  51097.0
# 2013-03-01   11.0  3.592926e+09  390692.0       5147.0  ...  51279.0
# 2013-04-01   11.1  3.512071e+09  390556.0       5142.0  ...  51373.0
# 2013-05-01   11.1  3.324249e+09  398700.0       5174.0  ...  51488.0
# ...           ...           ...       ...          ...  ...      ...
# 2021-08-01   16.5  5.103868e+09  518938.0       5260.0  ...  81990.0
# 2021-09-01   16.6  4.145083e+09  509936.0       5260.0  ...  82119.0
# 2021-10-01   16.7  3.578614e+09  520056.0       5266.0  ...  82328.0
# 2021-11-01   16.7  3.537141e+09  524947.0       5267.0  ...  82647.0
# 2021-12-01   16.8  3.963700e+09  514131.0       5269.0  ...  83072.0
#
#             취약계층(비율)    기온   월강수량    습도    일조량  지중온도   풍량      기압  \
# 2013-01-01  0.012209  -3.4   22.1  57.0  167.7  -2.0  2.7  1015.3
# 2013-02-01  0.012220  -1.2   74.1  54.0  187.2   0.4  2.9  1014.2
# 2013-03-01  0.012261   5.1   27.3  49.0  256.3   7.0  3.0  1007.3
# 2013-04-01  0.012284  10.0   71.7  54.0  213.2  11.5  3.4  1002.6
# 2013-05-01  0.012312  18.2  132.0  58.0  238.1  20.2  2.9  1001.5
# ...              ...   ...    ...   ...    ...   ...  ...     ...
# 2021-08-01  0.018563  25.9  211.2  74.0  127.3  28.2  2.1   998.6
# 2021-09-01  0.018574  22.6  131.0  71.0  182.0  24.6  2.3  1003.4
# 2021-10-01  0.018615  15.6   57.0  70.0  168.4  16.7  2.1  1011.0
# 2021-11-01  0.018681   8.2   62.4  68.0  163.6   7.9  2.1  1009.1
# 2021-12-01  0.018769   0.6    7.9  62.0  185.4   0.8  2.3  1014.4
#
#             물공급량\n(서울특별시)
# 2013-01-01     75389372.0
# 2013-02-01     69701347.0
# 2013-03-01     72139881.0
# 2013-04-01     79432696.0
# 2013-05-01     80596985.0
# ...                   ...
# 2021-08-01     72429478.0
# 2021-09-01     65857195.0
# 2021-10-01     62968217.0
# 2021-11-01     67368712.0
# 2021-12-01     64739104.0
#
# [108 rows x 28 columns]

# %% [markdown]
# ## Correlation
# - 세 가지의 카테고리로 나누어 살펴보기 (1.계절성 / 2.지역성 / 3.사회성)

# %%
data_X.columns
# Out:
# Index(['총인구수', '세대수', '세대당 인구', '남자 인구수', '여자 인구수', '남여 비율', '고령화비율', '전력사용량',
#        '산업체 수', '100인 이상 사업장', '산업단지면적', '연간 가계소득', '연간 고등학교 졸업(명)',
#        '연간 고등학교 졸업자 비율', '연간 인건비', '연간 평균 수입대비 인건비', '취업률(명)', '고용보험자 비율',
#        '취약계층(개)', '취약계층(비율)', '기온', '월강수량', '습도', '일조량', '지중온도', '풍량', '기압'],
#       dtype='object')

# %%
# 1.계절성 (기온, 강수량, 습도, 일조, 지면온도, 풍속, 기압)
cols_seasonality = ['기온', '월강수량', '습도', '일조량', '지중온도', '풍량', '기압']
data_seasonality = pd.concat([data_X[cols_seasonality], data_y], axis=1)

# %%
plt.figure(figsize=(10, 8))
data_seasonality.corr()
heatmap = sns.heatmap(data_seasonality.corr(), cmap="RdYlBu_r", annot=True, annot_kws={"fontsize":15})
heatmap.set_title('Correlation Heatmap (Seasonality Features vs Water Demand)', fontdict={'fontsize':20}, pad=12)
plt.show()

# %% [markdown]
# - 기온&지중온도는 0.4의 유의미한 양의 상관성
# - 기압은 -0.4정도의 역상관성
# - 애초에 기온과 지중온도는 0.99의 상관성을 가지며, 기압 또한 (기온, 지중온도와 -0.9의 상관성을 가짐)
#     - 동일한 변수로 보아도 무방함

# %%
# 2.지역성 (총인구수, 세대수, 세대당 인구, 남자 인구수, 여자 인구수, 남여 비율, 고령화비율, 전력사용량, 산업체 수, 100인 이상 사업장, 산업단지면적)
cols_regional = ['총인구수', '세대수', '세대당 인구', '남자 인구수', '여자 인구수', '남여 비율', '고령화비율', '전력사용량', '산업체 수', '100인 이상 사업장', '산업단지면적']
data_regional = pd.concat([data_X[cols_regional], data_y], axis=1)

# %%
plt.figure(figsize=(10, 8))
data_regional.corr()
heatmap = sns.heatmap(data_regional.corr(), cmap="RdYlBu_r", annot=True, annot_kws={"fontsize":12})
heatmap.set_title('Correlation Heatmap (Regional Features vs Water Demand)', fontdict={'fontsize':20}, pad=12)
plt.show()

# %% [markdown]
# - 인구수(총인구, 세대당인구, 남자인구, 여자인구, 남여비율)과 0.6의 상관성
#     - 인구수는 서로 1에 가까운 상관성을 가짐 (공선성)
#     - 세대수는 왜 -1에 가깝지??...
# - 세대수, 고령화비율, 산업 관련3개 인자와는 -0.44 ~ -0.48의 상관성을 가짐
#     - 산업체 관련 입력변수는 유사한 음의 상관성을 갖지만 서로 영향이 별로 없음

# %%
# 3.사회성 (연간 가계소득, 연간 고등학교 졸업(명), 연간 고등학교 졸업자 비율, 연간 인건비, 연간 평균 수입대비 인건비, 취업률(명), 고용보험자 비율, 취약계층(개), 취약계층(비율))
cols_social = ['연간 가계소득', '연간 고등학교 졸업(명)', '연간 고등학교 졸업자 비율', '연간 인건비', '연간 평균 수입대비 인건비', '취업률(명)', '고용보험자 비율', '취약계층(개)', '취약계층(비율)']
data_social = pd.concat([data_X[cols_social], data_y], axis=1)

# %%
plt.figure(figsize=(10, 8))
data_social.corr()
heatmap = sns.heatmap(data_social.corr(), cmap="RdYlBu_r", annot=True, annot_kws={"fontsize":12})
heatmap.set_title('Correlation Heatmap (Social Features vs Water Demand)', fontdict={'fontsize':20}, pad=12)
plt.show()

# %%
data_corr = pd.concat([data_seasonality.corr()[-1:].T[:-1], data_regional.corr()[-1:].T[:-1], data_social.corr()[-1:].T[:-1]])
data_corr.columns = ['상관계수']
data_corr.sort_values(by='상관계수', ascending=True, inplace=True)

# %%
data_corr.plot.barh(figsize=(5,9))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Save Cleaned Dataset

# %%
data_Xy.to_csv('../data/02_Cleaned/Seoul(2013-).csv')

# %% [markdown]
# ## MODELLING
# - 공선성을 띄는 변수를 제거할 수도 있지만, 일단 다 때려넣고 수행해보기로 함

# %% [markdown]
# ### Pycaret

# %%
import pycaret
from pycaret.regression import *

# %%
data_train = data_Xy.sample(frac=0.9, random_state=42)
data_valid = data_Xy.drop(data_train.index)
data_train.reset_index(drop=True, inplace=True)
data_valid.reset_index(drop=True, inplace=True)
print(f'Data for Train: {data_train.shape}')
print(f'Data for Valid: {data_valid.shape}')
# Out:
# Data for Train: (86, 28)
# Data for Valid: (22, 28)

# %%
caret_101 = setup(data = data_Xy,
                  target = '물공급량\n(서울특별시)',
                  train_size = 0.9,
                  normalize = True,
                  normalize_method = 'minmax',
                  fold = 5,
                  fold_strategy = 'timeseries',
                  remove_multicollinearity = True,
                  session_id=101)
# Out:
# <style type="text/css">
# #T_f1173_row27_col1, #T_f1173_row40_col1, #T_f1173_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f1173">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f1173_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f1173_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1173_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f1173_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_f1173_row0_col1" class="data row0 col1" >101</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f1173_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f1173_row1_col1" class="data row1 col1" >물공급량
# (서울특별시)</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f1173_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_f1173_row2_col1" class="data row2 col1" >(108, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f1173_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_f1173_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f1173_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_f1173_row4_col1" class="data row4 col1" >27</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f1173_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_f1173_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f1173_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_f1173_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f1173_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_f1173_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f1173_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_f1173_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f1173_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_f1173_row9_col1" class="data row9 col1" >(97, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f1173_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_f1173_row10_col1" class="data row10 col1" >(11, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f1173_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_f1173_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f1173_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_f1173_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f1173_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_f1173_row13_col1" class="data row13 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f1173_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_f1173_row14_col1" class="data row14 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f1173_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_f1173_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f1173_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_f1173_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f1173_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_f1173_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f1173_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_f1173_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f1173_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_f1173_row19_col1" class="data row19 col1" >7405</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f1173_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_f1173_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_f1173_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_f1173_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_f1173_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_f1173_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_f1173_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_f1173_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_f1173_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_f1173_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_f1173_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_f1173_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_f1173_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_f1173_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_f1173_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_f1173_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_f1173_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_f1173_row28_col1" class="data row28 col1" >minmax</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_f1173_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_f1173_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f1173_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_f1173_row30_col0" class="data row30 col0" >Transformation

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_3cb51 th {
#   text-align: left;
# }
# #T_3cb51_row0_col0, #T_3cb51_row0_col2, #T_3cb51_row1_col0, #T_3cb51_row1_col1, #T_3cb51_row1_col3, #T_3cb51_row1_col4, #T_3cb51_row1_col5, #T_3cb51_row1_col6, #T_3cb51_row2_col0, #T_3cb51_row2_col1, #T_3cb51_row2_col2, #T_3cb51_row2_col3, #T_3cb51_row2_col4, #T_3cb51_row2_col5, #T_3cb51_row2_col6, #T_3cb51_row3_col0, #T_3cb51_row3_col1, #T_3cb51_row3_col2, #T_3cb51_row3_col3, #T_3cb51_row3_col4, #T_3cb51_row3_col5, #T_3cb51_row3_col6, #T_3cb51_row4_col0, #T_3cb51_row4_col1, #T_3cb51_row4_col2, #T_3cb51_row4_col3, #T_3cb51_row4_col4, #T_3cb51_row4_col5, #T_3cb51_row4_col6, #T_3cb51_row5_col0, #T_3cb51_row5_col1, #T_3cb51_row5_col2, #T_3cb51_row5_col3, #T_3cb51_row5_col4, #T_3cb51_row5_col5, #T_3cb51_row5_col6, #T_3cb51_row6_col0, #T_3cb51_row6_col1, #T_3cb51_row6_col2, #T_3cb51_row6_col3, #T_3cb51_row6_col4, #T_3cb51_row6_col5, #T_3cb51_row6_col6, #T_3cb51_row7_col0, #T_3cb51_row7_col1, #T_3cb51_row7_col2, #T_3cb51_row7_col3, #T_3cb51_row7_col4, #T_3cb51_row7_col5, #T_3cb51_row7_col6, #T_3cb51_row8_col0, #T_3cb51_row8_col1, #T_3cb51_row8_col2, #T_3cb51_row8_col3, #T_3cb51_row8_col4, #T_3cb51_row8_col5, #T_3cb51_row8_col6, #T_3cb51_row9_col0, #T_3cb51_row9_col1, #T_3cb51_row9_col2, #T_3cb51_row9_col3, #T_3cb51_row9_col4, #T_3cb51_row9_col5, #T_3cb51_row9_col6, #T_3cb51_row10_col0, #T_3cb51_row10_col1, #T_3cb51_row10_col2, #T_3cb51_row10_col3, #T_3cb51_row10_col4, #T_3cb51_row10_col5, #T_3cb51_row10_col6, #T_3cb51_row11_col0, #T_3cb51_row11_col1, #T_3cb51_row11_col2, #T_3cb51_row11_col3, #T_3cb51_row11_col4, #T_3cb51_row11_col5, #T_3cb51_row11_col6, #T_3cb51_row12_col0, #T_3cb51_row12_col1, #T_3cb51_row12_col2, #T_3cb51_row12_col3, #T_3cb51_row12_col4, #T_3cb51_row12_col5, #T_3cb51_row12_col6, #T_3cb51_row13_col0, #T_3cb51_row13_col1, #T_3cb51_row13_col2, #T_3cb51_row13_col3, #T_3cb51_row13_col4, #T_3cb51_row13_col5, #T_3cb51_row13_col6, #T_3cb51_row14_col0, #T_3cb51_row14_col1, #T_3cb51_row14_col2, #T_3cb51_row14_col3, #T_3cb51_row14_col4, #T_3cb51_row14_col5, #T_3cb51_row14_col6, #T_3cb51_row15_col0, #T_3cb51_row15_col1, #T_3cb51_row15_col2, #T_3cb51_row15_col3, #T_3cb51_row15_col4, #T_3cb51_row15_col5, #T_3cb51_row15_col6, #T_3cb51_row16_col0, #T_3cb51_row16_col1, #T_3cb51_row16_col2, #T_3cb51_row16_col3, #T_3cb51_row16_col4, #T_3cb51_row16_col5, #T_3cb51_row16_col6, #T_3cb51_row17_col0, #T_3cb51_row17_col1, #T_3cb51_row17_col2, #T_3cb51_row17_col3, #T_3cb51_row17_col4, #T_3cb51_row17_col5, #T_3cb51_row17_col6 {
#   text-align: left;
# }
# #T_3cb51_row0_col1, #T_3cb51_row0_col3, #T_3cb51_row0_col4, #T_3cb51_row0_col5, #T_3cb51_row0_col6, #T_3cb51_row1_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_3cb51_row0_col7, #T_3cb51_row2_col7, #T_3cb51_row3_col7, #T_3cb51_row4_col7, #T_3cb51_row5_col7, #T_3cb51_row6_col7, #T_3cb51_row13_col7, #T_3cb51_row16_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_3cb51_row1_col7, #T_3cb51_row7_col7, #T_3cb51_row8_col7, #T_3cb51_row9_col7, #T_3cb51_row10_col7, #T_3cb51_row11_col7, #T_3cb51_row12_col7, #T_3cb51_row14_col7, #T_3cb51_row15_col7, #T_3cb51_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_3cb51">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3cb51_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3cb51_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_3cb51_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_3cb51_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_3cb51_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_3cb51_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_3cb51_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_3cb51_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3cb51_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_3cb51_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_3cb51_row0_col1" class="data row0 col1" >4105310.8340</td>
#       <td id="T_3cb51_row0_col2" class="data row0 col2" >29313637667377.6758</td>
#       <td id="T_3cb51_row0_col3" class="data row0 col3" >5304889.3288</td>
#       <td id="T_3cb51_row0_col4" class="data row0 col4" >0.4817</td>
#       <td id="T_3cb51_row0_col5" class="data row0 col5" >0.0699</td>
#       <td id="T_3cb51_row0_col6" class="data row0 col6" >0.0544</td>
#       <td id="T_3cb51_row0_col7" class="data row0 col7" >0.0320</td>
#     </tr>
#     <tr>
#       <th id="T_3cb51_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_3cb51_row1_col0" class="data row1 col0" >Ridge Regression</td>
#       <td id="T_3cb51_row1_col1" class="data row1 col1" >4250895.2500</td>
#       <td id="T_3cb51_row1_col2" class="data row1 col2" >29118635075174.3984</td>
#       <td id="T_3cb51_row1_col3" class="data row1 col3" >5324680.4000</td>
#       <td id="T_3cb51_row1_col4" class="data row1 col4" >0.4809</td>
#       <td id="T_3cb51_row1_col5" class="data row1 col5" >0.0708</td>
#       <td id="T_3cb51_row1_col6" class="data row1 col6" >0.0574</td>
#       <td id="T_3cb51_row1_col7" class="data row1 col7" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_3cb51_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_3cb51_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_3cb51_row2_col1" class="data row2 col1" >4240954.7225</td>
#       <td id="T_3cb51_row2_col2" class="data row2 col2" >29646306925887.4883</td>
#       <td id="T_3cb51_row2_col3" class="data row2 col3" >5318616.5594</td>
#       <td id="T_3cb51_row2_col4" class="data row2 col4" >0.4465</td>
#       <td id="T_3cb51_row2_col5" class="data row2 col5" >0.0710</td>
#       <td id="T_3cb51_row2_col6" class="data row2 col6" >0.0569</td>
#       <td id="T_3cb51_row2_col7" class="data row2 col7" >0.0420</td>
#     </tr>
#     <tr>
#       <th id="T_3cb51_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_3cb51_row3_col0" class="data row3 col0" >AdaBoost Regressor</td>
#       <td id="T_3cb51_row3_col1" class="data row3 col1" >4244134.9750</td>
#       <td id="T_3cb51_row3_col2" class="data row3 col2" >30277873419652.8906</td>
#       <td id="T_3cb51_row3_col3" class="data row3 col3" >5428555.7537</td>
#       <td id="T_3cb51_row3_col4" class="data row3 col4" >0.4461</td>
#       <td id="T_3cb51_row3_col5" class="data row3 col5" >0.0719</td>
#       <td id="T_3cb51_row3_col6" class="data row3 col6" >0.0568</td>
#       <td id="T_3cb51_row3_col7" class="data row3 col7" >0.0140</td>
#     </tr>
#     <tr>
#       <th id="T_3cb51_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_3cb51_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_3cb51_row4_col1" class="data row4 col1" >4497010.5439</td>
#       <td id="T_3cb51_row4_col2" class="data row4 col2" >33872976647163.5469</td>
#       <td id="T_3cb51_row4_col3" class="data row4 col3" >5688405.2105</td>
#       <td id="T_3cb51_row4_col4" class="data row4 col4" >0.4177</td>
#       <td id="T_3cb51_row4_col5" class="data row4 col5" >0.0755</td>
#       <td id="T_3cb51_row4_col6" class="data row4 col6" >0.0598</td>
#       <td id="T_3cb51_row4_col7" class="data row4 col7" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_3cb51_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_3cb51_row5_col0" class="data row5 col0" >K Neighbors Regressor</td>
#       <td id="T_3cb51_row5_col1" class="data row5 col1" >4671766.2000</td>
#       <td id="T_3cb51_row5_col2" class="data row5 col2" >35032141502873.6016</td>
#       <td id="T_3cb51_row5_col3" class="data row5 col3" >5830668.2000</td>
#       <td id="T_3cb51_row5_col4" class="data row5 col4" >0.3735</td>
#       <td id="T_3cb51_row5_col5" class="data row5 col5" >0.0773</td>
#       <td id="T_3cb51_row5_col6" class="data row5 col6"

# %% [markdown]
# # TODOs
# - Pycaret
# -

# %% [markdown]
# # PLAYGROUND

# %%
# !pip install sklearn==0.23.2
